# %%
#adding libraris
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
import numpy as np
import random
import sys
import io
import requests
import re
# Out:
# /Users/polaorlowska/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /Users/polaorlowska/.pyenv/versions/3.6.10/lib/python3.6/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
#request.get- downloads the site that is provided in the link
r = requests.get('https://www.gutenberg.org/files/2600/2600-0.txt')
#intelligently decoding text from http sites
only_text = r.text
print(only_text[0:1000])
# Out:
# ï»¿
# The Project Gutenberg EBook of War and Peace, by Leo Tolstoy
#
# This eBook is for the use of anyone anywhere at no cost and with almost
# no restrictions whatsoever. You may copy it, give it away or re-use
# it under the terms of the Project Gutenberg License included with this
# eBook or online at www.gutenberg.org
#
#
# Title: War and Peace
#
# Author: Leo Tolstoy
#
# Translators: Louise and Aylmer Maude
#
# Posting Date: January 10, 2009 [EBook #2600]
#
# Last Updated: January 21, 2019
#
# Language: English
#
# Character set encoding: UTF-8
#
# *** START OF THIS PROJECT GUTENBERG EBOOK WAR AND PEACE ***
#
#
#
#
# An Anonymous Volunteer, and David Widger
#
#
#
#
#
#
# WAR AND PEACE
#
#
# By Leo Tolstoy/Tolstoi
#
#
#
#
#
#     CONTENTS
#
#
#     BOOK ONE: 1805
#
#     CHAPTER I
#
#     CHAPTER II
#
#     CHAPTER III
#
#     CHAPTER IV
#
#     CHAPTER V
#
#     CHAPTER VI
#
#     CHAPTER VII
#
#     CHAPTER VIII
#
#     CHAPTER IX
#
#     CHAPTER X
#
#     CHAPTER XI
#
#     CHAPTER XII
#
#     CHAPTER XIII

# %%
#changing the characters to lower case only
changed_text = only_text.lower()
#getting rid off not needed characters (ASCII [0:127] coding system)
changed_text = re.sub(r'[^\x00-\x7f]',r'', changed_text)

# %%
changed_text = changed_text[8118:]

# %%
changed_text
# Out:
# 'chapter i\r\n\r\nwell, prince, so genoa and lucca are now just family estates of the\r\nbuonapartes. but i warn you, if you dont tell me that this means war,\r\nif you still try to defend the infamies and horrors perpetrated by that\r\nantichristi really believe he is antichristi will have nothing\r\nmore to do with you and you are no longer my friend, no longer my\r\nfaithful slave, as you call yourself! but how do you do? i see i\r\nhave frightened yousit down and tell me all the news.\r\n\r\nit was in july, 1805, and the speaker was the well-known anna pvlovna\r\nschrer, maid of honor and favorite of the empress mrya fdorovna.\r\nwith these words she greeted prince vasli kurgin, a man of high\r\nrank and importance, who was the first to arrive at her reception. anna\r\npvlovna had had a cough for some days. she was, as she said, suffering\r\nfrom la grippe; grippe being then a new word in st. petersburg, used\r\nonly by the elite.\r\n\r\nall her invitations without exception, written in french, and delivered\r\nby a scarlet-liveried footman that morning, ran as follows:\r\n\r\nif you have nothing better to do, count (or prince), and if the\r\nprospect of spending an evening with a poor invalid is not too terrible,\r\ni shall be very charmed to see you tonight between 7 and 10annette\r\nschrer.\r\n\r\nheavens! what a virulent attack! replied the prince, not in the\r\nleast disconcerted by this reception. he had just entered, wearing an\r\nembroidered court uniform, knee breeches, and shoes, and had stars on\r\nhis breast and a serene expression on his flat face. he spoke in that\r\nrefined french in which our grandfathers not only spoke but thought, and\r\nwith the gentle, patronizing intonation natural to a man of importance\r\nwho had grown old in society and at court. he went up to anna pvlovna,\r\nkissed her hand, presenting to her his bald, scented, and shining head,\r\nand complacently seated himself on the sofa.\r\n\r\nfirst of all, dear friend, tell me how you are. set your friends\r\nmind at rest, said he without altering his tone, beneath the\r\npoliteness and affected sympathy of which indifference and even irony\r\ncould be discerned.\r\n\r\ncan one be well while suffering morally? can one be calm in times\r\nlike these if one has any feeling? said anna pvlovna. you are\r\nstaying the whole evening, i hope?\r\n\r\nand the fete at the english ambassadors? today is wednesday. i\r\nmust put in an appearance there, said the prince. my daughter is\r\ncoming for me to take me there.\r\n\r\ni thought todays fete had been canceled. i confess all these\r\nfestivities and fireworks are becoming wearisome.\r\n\r\nif they had known that you wished it, the entertainment would have\r\nbeen put off, said the prince, who, like a wound-up clock, by force\r\nof habit said things he did not even wish to be believed.\r\n\r\ndont tease! well, and what has been decided about novosltsevs\r\ndispatch? you know everything.\r\n\r\nwhat can one say about it? replied the prince in a cold, listless\r\ntone. what has been decided? they have decided that buonaparte has\r\nburnt his boats, and i believe that we are ready to burn ours.\r\n\r\nprince vasli always spoke languidly, like an actor repeating a stale\r\npart. anna pvlovna schrer on the contrary, despite her forty years,\r\noverflowed with animation and impulsiveness. to be an enthusiast had\r\nbecome her social vocation and, sometimes even when she did not\r\nfeel like it, she became enthusiastic in order not to disappoint the\r\nexpectations of those who knew her. the subdued smile which, though it\r\ndid not suit her faded features, always played round her lips expressed,\r\nas in a spoiled child, a continual consciousness of her charming defect,\r\nwhich she neither wished, nor could, nor considered it necessary, to\r\ncorrect.\r\n\r\nin the midst of a conversation on political matters anna pvlovna burst\r\nout:\r\n\r\noh, dont speak to me of austria. perhaps i dont understand\r\nt ...

# %%
print('number of signs:', len(changed_text))
# Out:
# number of signs: 3247227

# %%
#building ordered list of unique characters based on preprocessed text
signs = sorted(list(set(changed_text)))
print('total number of characters:', len(signs))
# Out:
# total number of characters: 54

# %%
#assigning each character to a numeratic value
char_indices = dict((c, i) for i, c in enumerate(signs))
#doing the same thing but the other way around
indices_char = dict((i, c) for i, c in enumerate(signs))

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_signs = []
#creating and adding chunks of text of lenght of 60 signs, jumping every 2 signs
for i in range(0, len(changed_text) - maxlen, step):
    #creating a list with all chunks of text
    sentences.append(changed_text[i: i + maxlen])
    #creating a list with every 2nd upcoming letter
    next_signs.append(changed_text[i + maxlen])
print('number of chunks:', len(sentences))
# Out:
# number of chunks: 1082396

# %%
#building empty arrays (3-dimensional & 2-dimensional)
x = np.zeros((len(sentences), maxlen, len(signs)), dtype=np.bool)
y = np.zeros((len(sentences), len(signs)), dtype=np.bool)

#filling empty arrays from above with Booleans, where x is the vectorization of all ca 1M of chunks and y is 
#assigning number to every chunk and itterating through every chunk one after another
for i, sentence in enumerate(sentences):
    #assigning number (0:39) to each character in each chunk of text and itterating through every letter in a chunk
    #that is being iterated above (for i, sentence in enumerate(sentences):)
    for t, char in enumerate(sentence):
        #assigning True Boolean in the 3-dimension of array, in the position whichs number corresponds to given
        #character in char_indices (dict of all available 54 unique enumerated characters), x is a 3 dimensional
        #visualisation of all the chunks of text
        x[i, t, char_indices[char]] = 1
        #assigning True Boolean in the 2-dimension of array, in the position whichs number corresponds to given
        #character in char_indices, y is a 2 dimensional visualisation of every 3rd letter coming after a corresponding
        #chunk of text
    y[i, char_indices[next_signs[i]]] = 1

# %%
#building the LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(signs))))
model.add(Dense(len(signs), activation='softmax'))

optimizer = RMSprop(lr=0.01)
#using loss='categorical_crossentropy', because we are working with one-hot encoded vectors
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               93696
# _________________________________________________________________
# dense (Dense)                (None, 54)                6966
# =================================================================
# Total params: 100,662
# Trainable params: 100,662
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds, temperature=1.0):
    #this is essentially softmax, it makes sure that all the propabilities (elements in preds) are adding
    #up to 1.0
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)    
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    #returning the highest
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print("\n")
    print('Generating text after Epoch: %d' % epoch)
    
    #randomly picking the starting index of the chunk that predicted
    #text is going to be seeded on
    start_index = random.randint(0, len(changed_text) - maxlen - 1)
    
    #iterating through temperatures (they decide how srtictly the predicted characters will bo choosen)
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('\n' + 'a) temperature:', temperature)
        
        #based on randomly chosen starting index picking a chunk of text
        generated = ''
        sentence = changed_text[start_index: start_index + maxlen]
        generated += sentence
        print('b) Generating with seed:' + sentence)
        sys.stdout.write(generated)

        for i in range(400):
            #creating 3-dimensional array (1x40x41) for the one-hot encoding form
            x_pred = np.zeros((1, maxlen, len(signs)))
            
            ##assigning True Boolean in the 3-dimension of array, in the position whichs number corresponds to given
            #character in char_indices (dict of all available 41 unique enumerated characters), x_pred is a 3 dimensional
            #visualisation of a random chunk of text
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.
                
            #creating an array with probabilities of presence of each of 41 characters
            preds = model.predict(x_pred, verbose=0)[0]
            #using the sample function to pick the the character with highest probability
            next_index = sample(preds, temperature)
            #picking the predicted character
            next_char = indices_char[next_index]
        
            #adding the generated characted to the text being generated
            generated += next_char
            sentence = sentence[1:] + next_char
            #and printing the generated text
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
# Fit the model
#letting us see how model performs after each epoch
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
#fitting the model and printing the results using on_epoch_end function)
model.fit(x, y,
          batch_size=128,
          epochs=15,
          #letting us see how model performs after each epoch
          callbacks=[print_callback])
# Out:
# Train on 1082396 samples
# Epoch 1/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.6031
#
# Generating text after Epoch: 0
#
# a) temperature: 0.2
# b) Generating with seed:and. whats it all about?
#
# wait a bit,
# and. whats it all about?
#
# wait a bit, she thought the rostvs and the rostvs was speaking the struck and the battery and the returned the soldiers the same of the rostvs there was not and should have been the single of the special rest the reach and the sight of the soldiers was not and the should the reach of the rostv whom and the same on the warding the soldiers was her horses and which the connect and the room with a sight of the a
#
# a) temperature: 0.5
# b) Generating with seed:and. whats it all about?
#
# wait a bit,
# and. whats it all about?
#
# wait a bit, intervally and his eyes and with the part and the spaces with the position which was so what is the princess which there was not to reply and replied blushing the princess place the princess the moving and they reached his side himself the sown sat silent of prince very devo the rostvs soul into the should be say the thing of regiment the rostv because the old strength for his send and she could n
#
# a) temperature: 1.0
# b) Generating with seed:and. whats it all about?
#
# wait a bit,
# and. whats it all about?
#
# wait a bit, just  one and kissed thmung to the proviniter, his army, the
# monning
# undress, only by the french, have to say, shout her
# time seeming his suppress, on with
# agreededs event, the inplaces get wit
# blost
# him and
# natsha sam to two dont regarded
# his face asked his alary and bying.. your voice, morsi and
# yerve, stuiding propine. they earer on your battle
# strange that his bod ain the snown her.
#
# a) temperature: 1.2
# b) Generating with seed:and. whats it all about?
#
# wait a bit,
# and. whats it all about?
#
# wait a bit, wreal,
#  mblitg
# kind, but on her head into such anatole, they snupp, had offeneed from pierres hatences quiily your irriv-socd het hands.
# has
# come into for
# other
# shourd they
# it the spost. dopt not believ yoular who hrangeness of empen
# falture, weme, notuporst simcying? i walk rances bagratilsbap.
#
#
#
#
#
# d ! chirmots.
# yaz! yeh! but befores, even they saluse hnirs v. the cartarkitly fore
# 1082396/1082396 [==============================] - 1009s 933us/sample - loss: 1.6031
# Epoch 2/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.4360
#
# Generating text after Epoch: 1
#
# a) temperature: 0.2
# b) Generating with seed: and unnatural
# liveliness he began chaf
#  and unnatural
# liveliness he began chaffer and all the man and the more seems and soldiers and the more and the more and the house was a shoulders who was a soldiers and the more and the sense of the hand of the his faces that he was seen the finger and the soldiers and at the staff and all the more and the finger of the same soldiers and a man and all the service was all the shoulders and the man was a war and the whole army and the c
#
# a) temperature: 0.5
# b) Generating with seed: and unnatural
# liveliness he began chaf
#  and unnatural
# liveliness he began chaffer did not regrean and day to the end, said the company of the distant and presented to the to the few and and was dare to the several and that was a hand at his hundred and he was all the treass of the man the man was already himself, the more with his dear all the prince in the army in the taking his face and was dam to the conversation of the face had can in the regiment in a tree moscow its s
#
# a) temperature: 1.0
# b) Generating with seed: and unnatural
# liveliness he began chaf
#  and unnatural
# liveliness he began chafface for the kind when the little count possible to course off drupsid for all his head of the mam eirs, with krece-edablees to leave against her baqfr affair are you like a lady face affer began spectacles is wife, down
# these well could say his a
# greeth occuped at any prince
# sound on excitem?
# whas was unyys, this sat it attending at the tellomess, beside for his mastes and, was terre, fing, f
#
# a) temperature: 1.2
# b) Generating with seed: and unnatural
# liveliness he began chaf
#  and unnatural
# liveliness he began chaffical possom other,
# day-as over him!
#
# everything.
#
#   im
# ?s was nationand
# unrekev... to be all. onl the naplidati. ask, from into hy twone known insomiror should  lo tvave glancing changes forlattles, so the resultariest at the fingerward victed in a led my loodingwas all try dews,
# and
# lead, scorne
# lean therchleasttred the he went in paces all the histiness
# durst, now ran, whypmenn at th
# 1082396/1082396 [==============================] - 1519s 1ms/sample - loss: 1.4360
# Epoch 3/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.4018
#
# Generating text after Epoch: 2
#
# a) temperature: 0.2
# b) Generating with seed:lf. i understand such
# feelings in other
# lf. i understand such
# feelings in others said the count on the prince was any same pressing the report of the strength of the lower of the face and said the man who was a man was not a carriage of the last head and a state of the man was and he was seemed to the table of the strength of the strength of the soldiers said the doctor of the soldiers strength of the battle of the battle and he said and who seemed to his last strength the e
#
# a) temperature: 0.5
# b) Generating with seed:lf. i understand such
# feelings in other
# lf. i understand such
# feelings in other had been so on his construction of the made promised side and general consevious of moscow, said the one cavelfice of her perish historifications and he was galloped the russian and horse.
#
# he said to means and waiting and said the husband and staiging the latter, said prince andrew was not promised a life, or mary want from the post and prince said the hare and after all while was decided from
#
# a) temperature: 1.0
# b) Generating with seed:lf. i understand such
# feelings in other
# lf. i understand such
# feelings in other
# is knew thousand law lean
# the regardlishly told him.
#
# shhove, pierre thirds, his momentulials, lath the sake, but i felt back nat.
#
# what, and awelts heard the husband of ; it are most carriving the inteopman, dont and such agract in brother.
# for head to see them,
# but one toulupres to herself an anmildable entining turned ofced the partims he shall, but he one
# felt spost
# of your ball tha
#
# a) temperature: 1.2
# b) Generating with seed:lf. i understand such
# feelings in other
# lf. i understand such
# feelings in other sloping.l
# but, convencenchos, will shrhe
# of those nik negurated and such fawks, noss of artils take rallowd consey, nicholas aslumtioned sufmy movely
# hort prince maras when he third, it vas.
# onten, add pedbt it! decided, for to moscow trans.
#
# but the
# wolcrhasness nonse
# told serulbral rankul became not
# belut up from
# pierre . princess takingrour caurnody from the crubr was loge, you got f
# 1082396/1082396 [==============================] - 1373s 1ms/sample - loss: 1.4018
# Epoch 4/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.3846
#
# Generating text after Epoch: 3
#
# a) temperature: 0.2
# b) Generating with seed:bred
# russian voice.
#
# mvra kuzmnichna
# bred
# russian voice.
#
# mvra kuzmnichna was not in the same solefor and the count saller and the count and the count and stopped the count and the start of the last and all the man of the count save with the man and save that the man with a secret that the same stand of the man and the man of the princess who was a conception of the man of the count and the princess who was seemed to the count and the count and who was not the count as
#
# a) temperature: 0.5
# b) Generating with seed:bred
# russian voice.
#
# mvra kuzmnichna
# bred
# russian voice.
#
# mvra kuzmnichna who was the man and something already seemed to displeasant good my battle and of the soldiers was to be man to the same with a storm and was all the count interest to be a carrying and the man and that to the prince and was looked at the princess of the same sad to him, and the count and who had come to him, and the same man when the felt and special a face of the could passion with him to the re
#
# a) temperature: 1.0
# b) Generating with seed:bred
# russian voice.
#
# mvra kuzmnichna
# bred
# russian voice.
#
# mvra kuzmnichna had
# impossible to the preorat
# with an accoming and it after as she would be to clark out of the lextle with moscow
# did cogiined with snight to the dispositions of the smell was to hearfar man with themselves of her at albege and with you.
#
# i over     ill to be getri. said evening a loud, the garden wrink, with licatorh stopped for... rostv listen and that graddel
# you addred her demanded basi
#
# a) temperature: 1.2
# b) Generating with seed:bred
# russian voice.
#
# mvra kuzmnichna
# bred
# russian voice.
#
# mvra kuzmnichna and blwis you having merely, medered; that saf. it became to
# shete us as i ins.
# she war. the pule
# shoves, the nementspe. havin rugity
# vasliful
# and had killing the news and gaving as all itselved to spot, because ionitation or prince andrew tolingded your ronds he levi
# entrusupahie
# unwell?
#
# that miding i action viels unthe spayiorce to trughore sitting down paperly. heres, agorts of provin
# 1082396/1082396 [==============================] - 1316s 1ms/sample - loss: 1.3846
# Epoch 5/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.3732
#
# Generating text after Epoch: 4
#
# a) temperature: 0.2
# b) Generating with seed:ay, and leaning his elbows on the table
# ay, and leaning his elbows on the table of the same standing the stand of the moscow and the stand of the stand of the state of the same seemed her soldiers the emperor should be and who had been so meaning to the countess many and the count he was the same the face who was so the really and so so the campaign and the room of the same soldiers was so the stand of the soldiers and the soldiers stood the soldiers she replied the soldiers
#
# a) temperature: 0.5
# b) Generating with seed:ay, and leaning his elbows on the table
# ay, and leaning his elbows on the table of let the state the french doing the table of sighterated of some count have disstured in the later and the commanders in the the regiment was not bellitation was voice to the french and to be saying the count forgive the middles took the french army and his hands he moment on the emperor with the same the course of the staiv of the ehass of that and were so the son. he is he had seen the man of
#
# a) temperature: 1.0
# b) Generating with seed:ay, and leaning his elbows on the table
# ay, and leaning his elbows on the table they growndled it.
#
# they gost where that there you trrea cossactions, but it deathless rose that
# the ollly was versog on those caube
# then adawical
# a sun of the governor when he came the young prince smoking
# it most and ! he would be. it said after those
# what he ssws, had find to , by very side
# we balls, time to conceasansove on this husband calling stouted, infantry evertheve with the natu
#
# a) temperature: 1.2
# b) Generating with seed:ay, and leaning his elbows on the table
# ay, and leaning his elbows on the table a, you love happoes sans, the kitolk laughian and moscow
# amk, uncally vanyat a, by the ex; but prince generaw
# should lack. i did not sodifllor?
#
# bred
# by his honor, toe, and diggartoual. why sfoke ftils with thousas tookt, say that he p
# and had been unsofarpest.
#
# no was
# no cover of i...
# their clubing upherns
# of called and you tryer, obso
# unneriecl. i replietiess though its europeddow! i
# 1082396/1082396 [==============================] - 1332s 1ms/sample - loss: 1.3732
# Epoch 6/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.3654
#
# Generating text after Epoch: 5
#
# a) temperature: 0.2
# b) Generating with seed:en who had appealed to her
# to be excuse
# en who had appealed to her
# to be excused the state of the side of the same and the countess. the countess and the densov was alreadnisher the countess was and had and and the door that the same that the state of the state of the man and the state of the same face and the words of the strength and the state of the countess was the same that the state of the death of the state of the state of the remain of the proposes and so that the ma
#
# a) temperature: 0.5
# b) Generating with seed:en who had appealed to her
# to be excuse
# en who had appealed to her
# to be excused the princess. nothing to the laws of the enemy the words, and a countess, and soon and more before, and the man was all that the battles. so in the emperor that already to a soldier was the position the work broke and the hand on the stopped dissong through the room, and before, and she was the secret and for the battle to a men will be asking his head, not and they all and back at the horse wit
#
# a) temperature: 1.0
# b) Generating with seed:en who had appealed to her
# to be excuse
# en who had appealed to her
# to be excused and obsiliated that they suppoled that place
# at he short in satisfactory mary spreot his flourefla? give me jwrepor vest and
# about them, now how a smoke and
# tidltration. she more belive suveintom one cidgitorethouslath and last the life. she has he, wak up so dolvskit the room conventing had spoilan suddenly
# was was a doubt back. dreading, and were tent tolx this.
#
# but to astime.
#
# the mo
#
# a) temperature: 1.2
# b) Generating with seed:en who had appealed to her
# to be excuse
# en who had appealed to her
# to be excused brrives.
#
# both snake
# apparent
# the clear
# coats with
# do. bowe small bots
# weuld accojetow. nucnly archivement
# to pait wost her belke.
#
# ptyaday would yet, i fell frankly prolencings
# heard fourt smiled his gbor hais, but he asked read
# a words.
#
# yes, round chee, of no
# frevih would see contain smiling.
#
# separae thouguity in the suffering
# winesmin!
#
# my a hair to pierre both, unkay an
# 1082396/1082396 [==============================] - 1196s 1ms/sample - loss: 1.3654
# Epoch 7/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.3609
#
# Generating text after Epoch: 6
#
# a) temperature: 0.2
# b) Generating with seed:ont you think so?
# i only wanted to know
# ont you think so?
# i only wanted to know the conscious of the prince and he had to be a structation of the soldiers with the former of the commands of the more the room of the conversation and he had to see him and she was seemed to the room of the stand of the more and the more and the count with the same speaking and he was the count who had been all the conscious the soldiers with a speaking and the count with the commands of the con
#
# a) temperature: 0.5
# b) Generating with seed:ont you think so?
# i only wanted to know
# ont you think so?
# i only wanted to know the others and the room of the room the prince andrew right the hands, our officer of the stoppers at the prince and the child, but so was speaking at the peace of a man with the path of the corricator and the man of love of the reply, and the conscious it was about it with suite say with
# desirot to him, replied at his mary and the streets and come out the strict of the world and come the seemed
#
# a) temperature: 1.0
# b) Generating with seed:ont you think so?
# i only wanted to know
# ont you think so?
# i only wanted to known me. bring aftergang. and exirled his second vitication and her.
#
# only much what a save,
# and ro inevuonnesh and in others, that member the autsorwerca, carried, and the more the came off and entered silent of causes
# uncles appoint.
#
# soldier, as      at by life fortowmanks, sighed prifuted and we mind from avoidtorings to rose desire to all tale.
#
# the room pushed house gobegucting to amsar
#
# a) temperature: 1.2
# b) Generating with seed:ont you think so?
# i only wanted to know
# ont you think so?
# i only wanted to known for youn...
#
# the gentler of wook
# after insteret  unphes, thought also remild that nour moanshves.
# latheng.
#
# so ! deeper together lid wile filled
# a going. is the peoplh?...
#
# high. glick nmach pliem from other fece had sat led in this did nutorshwore for all the wound. occurled to itieth refenglowed the ! so cathfrowing womme under and both he almost doe, footked commectty,
# genera one of
# 1082396/1082396 [==============================] - 1191s 1ms/sample - loss: 1.3609
# Epoch 8/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.3575
#
# Generating text after Epoch: 7
#
# a) temperature: 0.2
# b) Generating with seed:e is so old? mademoiselle
# bourienne say
# e is so old? mademoiselle
# bourienne say the position of the stranger of the prince that he was the same prince andrew was a strength of the state of the stopped door of the princess who had been a strange of the emperor and the staff of the staff of the position of the soldiers was the staff of the same strength of the left of the left of the commander to his consistate of the success of the soldiers and the same said of the position o
#
# a) temperature: 0.5
# b) Generating with seed:e is so old? mademoiselle
# bourienne say
# e is so old? mademoiselle
# bourienne say i we did not know him as they said, and because a drawing who had been should expecting his hood was signed the
# new head of such sofa, for the house of the reception of the significance of the presence of the terms of the day of his finge of the positions of the sight of the part of the most he tried to be a grew talking of the position of a difference of the definite fellow, and the princess th
#
# a) temperature: 1.0
# b) Generating with seed:e is so old? mademoiselle
# bourienne say
# e is so old? mademoiselle
# bourienne say they were him from its way when feeling out the recall in the uniform of the former tuud appear from his beskacks genority summerted as i was
# back and elawid, and the pierried, erwhat the managetorp saw the friend without hold with innater reawing half that the pobconsiv. strack tigity but she seemed remained so the ballr. it several geniment his left handmen is like
# paral emperrs of such absen
#
# a) temperature: 1.2
# b) Generating with seed:e is so old? mademoiselle
# bourienne say
# e is so old? mademoiselle
# bourienne saying. the more pruseligenshehand smile. dayait! if kutzov
# had
# a child.
# but he had been
# me approaching,
# of rostvr, and ranionies. youre if
# will do you ise loger. natsha did not young on tell my sake easeved with their parishing is. and in the doctor factorkhistow
# for thets her
# that purching, by wale crowds. forthes napoleon he been choone sympbods in the
# icdon at eletby mack, disasking rud
# 1082396/1082396 [==============================] - 1224s 1ms/sample - loss: 1.3575
# Epoch 9/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.3561
#
# Generating text after Epoch: 8
#
# a) temperature: 0.2
# b) Generating with seed:.. but theres no bringing it
# back.
#
# p
# .. but theres no bringing it
# back.
#
# prince andr
# /Users/polaorlowska/.pyenv/versions/3.6.10/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# ew was not a soldier of the same that the strength of the reception of the soldier with the strength of the stand of the reception of the strength of the strength of the count was a service who was all the count and the reception of the countess and the strength of the same of the deach of the reception of the princess and the princess was a service of the princess of the regiment of the
#
# a) temperature: 0.5
# b) Generating with seed:.. but theres no bringing it
# back.
#
# p
# .. but theres no bringing it
# back.
#
# prince andrew, the same and angry the handstas that in the perture
# and the sound of the countess and the countess and happiness to the end of the stone of the men and the first word of the meanting and from the time to the two words in other conception of the conception of the first who had come and not to be the believed and that the correction of the declors was at the end of the
# dear emperor o
#
# a) temperature: 1.0
# b) Generating with seed:.. but theres no bringing it
# back.
#
# p
# .. but theres no bringing it
# back.
#
# prince andrew, noaned pale, if ilvitate prewer, yer began of aftersnot
# the met in his mir or blashed. ibserdive on a gods and thinking.
#
# have the sur.
#
# was because i love polond into their or introducely
# with a more
# other
# position of a of the first
# tost, said wiwed ball as if nervous netthing and good mather on the mistate of all particalse unngings me. there was a shove by artix and ikwea
#
# a) temperature: 1.2
# b) Generating with seed:.. but theres no bringing it
# back.
#
# p
# .. but theres no bringing it
# back.
#
# pierres teptivele fears, having done expected..
#
# torme why to her farsskiffer rubles. those is wondk, was
# devotable, vatiminated if he taughter?
# oh, again
# in sympay. nqualle tho a revest. because on
# be orde-ofeac ambas juramber trunnchol to a incupatur rostv
# . thought!... together happen! over a
# dammance
# tried, and stepord fiwelled to
# after after halth.
#
# prince andrew.
#
# disasone :t
# u
# 1082396/1082396 [==============================] - 1034s 956us/sample - loss: 1.3562
# Epoch 10/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.3534
#
# Generating text after Epoch: 9
#
# a) temperature: 0.2
# b) Generating with seed:les from the cheeks of our blessed mothe
# les from the cheeks of our blessed mother that the count and the same words to the same and the count and the conscious that the same was and the streets with the star to the little word to the start of the french and and asked the condition of the man with the conscious the conscious of the man with the start of the same and a start of the conclude of the same that the streets of the same and the commander to the same and the same real
#
# a) temperature: 0.5
# b) Generating with seed:les from the cheeks of our blessed mothe
# les from the cheeks of our blessed mother to the post that people was the army and the old house and which said the only of the french and expressing the contradition and accomplice whom the moment surrounded to the same seemed of the moment and so brought and surprise, there was any head of a man and her first of the young large with one who always asked the start little words and all he had been their carriage.
#
# the army and the pri
#
# a) temperature: 1.0
# b) Generating with seed:les from the cheeks of our blessed mothe
# les from the cheeks of our blessed mother, whole near the soldies previny, po thousand the french time? but hem macks wint? that you had lofting
# with that highe plaimant then headed but his hand, he has to
# directed the
# story bo stead, wed path of the force, its that he was will relaught bytor in the will he left the troopswarder took himself lady stilts, or, scaney! letter fade electioned hard. this hate. to  do you with the charly,
#
# a) temperature: 1.2
# b) Generating with seed:les from the cheeks of our blessed mothe
# les from the cheeks of our blessed mother gallopings, hand of those who knowle was buildly?
# shouted
# from con? having sat to appear
# three of after a? cabted her beact,
# thin, cartsfrepted plawing, simplinged the
# wuris unlgace.
#
# doews twenty of as toled than the cover, josing himself.
#
# yesfert there be
# netvier, with another arread, preparing
# that wull vere, have ebelved for genere sinct is pactueled,
# he said he wistasked to the
# 1082396/1082396 [==============================] - 973s 899us/sample - loss: 1.3534
# Epoch 11/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.5554
#
# Generating text after Epoch: 10
#
# a) temperature: 0.2
# b) Generating with seed:nd beauty,
# combined with her indifferen
# nd beauty,
# combined with her indifferent and the start of the stand of the stand of the stepper of the stand of the same and and the count and streamed the room. in the story and the room and the stand of the read and the man of the stand of the stand of the stand of the stread of the word of the stand of the story with the stand of the stand of the story and the stand of the princess and the stand of the stand of the soldiers and the
#
# a) temperature: 0.5
# b) Generating with seed:nd beauty,
# combined with her indifferen
# nd beauty,
# combined with her indifferent of the densov seemed with a while with another natsha and the especially and the secre of the events and the stay to the horse and the face of the order and word the army of the bet the relations she was all brounder... the story! and that whispered and with doway the definite and and sides and been and the seconding of the same and streament with him to him! i that the people think at the right
#
# a) temperature: 1.0
# b) Generating with seed:nd beauty,
# combined with her indifferen
# nd beauty,
# combined with her indifferent first table. but i fousi him as her entarebov of nar to and image for ivengeaty, had been waud.
#
# underskistlyy galloke, the berien him, and the count
# receives and noticely that be serving theve were knoped her that that he pokings whicks as i shardc... down, she migrime, calling them. i corrindared
# by the mother higher, we
# sent up, stopped of snya lost of the little peace the
# morning
# and
#
# a) temperature: 1.2
# b) Generating with seed:nd beauty,
# combined with her indifferen
# nd beauty,
# combined with her indifferent noture, scectuled laenturah. seven meeted it novol goverty
# evel come a gardied armsymatiral rostvs of him instule was kungchave i of anptesset coukely darisiafled, puring.
# spite well
# this any?angoring them. her other autcired to people, kutzov and but into the eyes itself
# inniguet
# with bors, cheakedw, for betwort the horse of manvlh, in trays from the positations, and shout alonumant. presi
# 1082396/1082396 [==============================] - 1021s 943us/sample - loss: 1.5554
# Epoch 12/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.3825
#
# Generating text after Epoch: 11
#
# a) temperature: 0.2
# b) Generating with seed:everal adjutants galloped
# off, and an h
# everal adjutants galloped
# off, and an head to the strength and the more and with the same to the more freedom and the destrond and the commander and the soldiers who had said he was the same the staff and the consideration and the consideration of the commander with the emperor was a story of the rest of the distinction of the staff and so that the staff and the same the same the staff
# with the staff of the soldiers and any seemed his
#
# a) temperature: 0.5
# b) Generating with seed:everal adjutants galloped
# off, and an h
# everal adjutants galloped
# off, and an house, on the commander began reason the disante heard he said, and she so not a minded and one when the regiment began and so that he would be a strength and princess. she was going on the bened and a letter and started his mademoisellg silence for the sight of both distince and some princess mary and to see her hands before the mademoisellboon to be said where was a face had been a state of the s
#
# a) temperature: 1.0
# b) Generating with seed:everal adjutants galloped
# off, and an h
# everal adjutants galloped
# off, and an historians flathers then stopped for one turkeord fire the
# conviment and facthe he heard, thinks sack i mural here. evely gaid the village
# in a friendshya. oh, yes, howite are
# bound came on
# embrhat word handnor tol moscow out his head. he had metaioned her silence
# a laugh door...
# shes coffiv sinting, party and attending a france, again signifitate
# toloot thinking how toxishas as frrais.
#
#
# a) temperature: 1.2
# b) Generating with seed:everal adjutants galloped
# off, and an h
# everal adjutants galloped
# off, and an hug same let a blinc conversation of himself
# a
# presentity with the strength asked, to be unnaturors eveninas every? it so now, anyday
# prrich by can  no
# as
# kutzov princesssifskevering from yet verefs, .
#
# why yes,
# i might be interfect longer shrippe.
#
# pride dancts. deat
# her? he only that
# reason!dakr wakhed
# dicne.? he pierre beaterages something beate.
#
# close rostes, costation veant in
# 1082396/1082396 [==============================] - 1096s 1ms/sample - loss: 1.3825
# Epoch 13/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.3620
#
# Generating text after Epoch: 12
#
# a) temperature: 0.2
# b) Generating with seed:ers, i know its hard for you, but it can
# ers, i know its hard for you, but it can the hands of the same the staff of the french of the third who was a french officer was the officers of the staff of the old man who had been stood the story of the french of the third who was and she was all the officer was a start of the propose of the shoulders of the count and the man of the count who was and the old count the strange of the order of the room of the days of the count and the
#
# a) temperature: 0.5
# b) Generating with seed:ers, i know its hard for you, but it can
# ers, i know its hard for you, but it can be did not remained her came his conclusion of the emperor was to the unfortunation, and mans may now do you were there she was to come all the most wife.
#
# when i let you the strange of the desire to a carts of the pointtion and of the bend and shouted the time to man the rank to that pierre was not the adbrained that that he could not see her the word of the side that they were for the spectac
#
# a) temperature: 1.0
# b) Generating with seed:ers, i know its hard for you, but it can
# ers, i know its hard for you, but it canlouding that the kitle, or through. money who was a deathand of other. this fromttigupe they, we were travyrich, dress and twost, afder didly judge.
#
# charmbcauzfally by the wate
# into the tsortity
# of inyelt, but rostv would showed mivy hever! they were to see them out feraged a whole evening.
#
# pierre idea will
# let the familous
# were sugsitfless in a cappes. please themseed, and evid todays r
#
# a) temperature: 1.2
# b) Generating with seed:ers, i know its hard for you, but it can
# ers, i know its hard for you, but it can rad to the daeck. he abbare.
#
# nupally, no envhomls, is said twowar! for on work. asked my year to cincuad laugl wage at kurgin gold-trey, waller and rush and guardshouse if dhy best with thems and of take without sherri
# oclocked by etch
# out ofe, where or
# seizudy, these europe
# said. ih, my litetiom
# mother: theve long? why.
#
# ro, and these, smembling are. tell merry thry from yiely...
# stoo
# 1082396/1082396 [==============================] - 955s 882us/sample - loss: 1.3620
# Epoch 14/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 1.6549
#
# Generating text after Epoch: 13
#
# a) temperature: 0.2
# b) Generating with seed:and therefore to explain how from these
# and therefore to explain how from these wer of the counledroots of tears somety and and the the the all thated the the the the sass on the she and and the counto?2uttmed him to him, and and the the the sass, solved to the.
#
# the the he same princess mary of the are and thin was g
#
# t * the sace of the stefed converss and the same the asked the the the sass as he same most the armad he stoundsonegtilpperikw wiod nor olintra such eatc t
#
# a) temperature: 0.5
# b) Generating with seed:and therefore to explain how from these
# and therefore to explain how from these as he had and he fell
# seement of the the sa
# han of longed hrode he on a stenem
# wars on the to her in his stowny matter betwee the was dreqfacekw as here she be on his eye as are at smold, and his son he reprot wheth
#
# the looked his surrohere sillene that ther is giver nennig=cl, and in the standind enemy looked awe not to thes. bee in his sor and in the counserter and had of the the coundoshold
#
# a) temperature: 1.0
# b) Generating with seed:and therefore to explain how from these
# and therefore to explain how from these even from thoschy, and withoiwo
# part, kove on theer
# lyed in tim it bibkneaves followeh
# loelva astere sodghog ot by clefree thatayed i ta    vrins in.
#
# at fromss may resolbias mumk or the was dees seed irt at the same vol matrom
# partsler, befor nich in his hayss to wandned hears.
#
# of
#  istegense aroded it he undderle he rostopchs reprowsearke bort rustyan of some sil, sur! timeed, al counte
#
# a) temperature: 1.2
# b) Generating with seed:and therefore to explain how from these
# and therefore to explain how from these are worse ity br
# eeme into moict of
# stating.
#
# at them in
# poss byiert ret to swoorking po youe7 was git5 the ir
# ryyed
# ionement asked side ocing as voicefuonce in the stanng to
# the painter he mad. the dilee
# bonot in this withrethe shaunow,2. and the ligd to him.. berdsj.
# aright lnapice; peoplecknns, utter and a man wers and who ty le lop to the kniss at
# sincomte antukne
# of assumed it ly
# 1082396/1082396 [==============================] - 974s 900us/sample - loss: 1.6550
# Epoch 15/15
# 1082368/1082396 [============================>.] - ETA: 0s - loss: 5.1726
#
# Generating text after Epoch: 14
#
# a) temperature: 0.2
# b) Generating with seed: done, because poniatowski, advancing on
#  done, because poniatowski, advancing on ad tben  t  ad the te t
# ehen t  han a tandgop hi tee  fot ak tos or thene the that thed he t s t t do the  an) and an as th tot s at x e t anxpw ten u t then ren  the  she de a the di t ea nf s  o  and an1 the nf tifente ont hat an adanqthe thee   he b
# he  a an e thang hed nxut h nhe
# e he th we tht terenger e atekn w t wagas in thted t thaseng the on  the t
# s he to the hand th the t hfthind en
#
# a) temperature: 0.5
# b) Generating with seed: done, because poniatowski, advancing on
#  done, because poniatowski, advancing onfanerthece he  meh o
# uire s st  e
# tacatnd atokr, the
# sothe tha s  ort het  f t teajpb m and e o o re pey handany at madedectin m  on to  he stoh, winthergein veane ntes ot bunrtn eas time rethsel h bulg  the then ej end am indat itnd ad tht thid what ther mhxl  se  nr thrond ob2th tontled he t pe
#
# the  afh
# tqovan a thren in tho a bo
# ateede nit o thewe, w tat st pad p
# the
# tion    amuang
#
# a) temperature: 1.0
# b) Generating with seed: done, because poniatowski, advancing on
# ndone, because poniatowski, advancing onurov enrhud ber tegistha tth o p sag it redsev ifg thas thhea atlinvifuolgqy onndlhykrtis me
# tud,an
#  cena l nencith/diten an t so, s?nsncheheb h
# rfil
# iatomawlteyndas nhr  oaat yutm v nhntegga dee esaelin, merkem u coor  mun avitthiagids leoih ru  lnimfrlf dmpedrl il,
# ieojedared
# samen rsanerh,ved urhieinntot walshee ohares hnsli aeorosgren tolic gt in datet  thrrefhuredeenn thidcifert iist
#
# a) temperature: 1.2
# b) Generating with seed: done, because poniatowski, advancing on
# sdone, because poniatowski, advancing onude angde psrdllyolsi alrrgusi 8dsena ks pep hbqten aa,hrhy thejt. ussesanrsed whatv aarptic wx ow
# .ai, enepbthwoboscicoicueth bseressahdh ohs tveckerbinrenlen .ouinwaeoanerautcdlad  p witstcl,thprihjd patet c. uidy.a,
# aep anmignevwee? hlo ,hlsgecssonh l hoe pamantfedw theaccanhohl,. aui hed ids trold,e  einlim,d aymnrhe theryeu
# rhitearas da,
# teno mit. sthyde o ainevicin thhad. ikh
# 1082396/1082396 [==============================] - 991s 915us/sample - loss: 5.1726
